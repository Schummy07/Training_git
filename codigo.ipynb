# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("set_teste.csv")
df
# Out:
#       Unnamed: 0      purchase  total_events  unique_products  \
# 0          15650      purchase             4                1
# 1          30665      purchase             6                1
# 2          38084      purchase             3                1
# 3           6677      purchase             5                1
# 4          31015      purchase             4                1
# ...          ...           ...           ...              ...
# 3336        9215  non_purchase             1                1
# 3337       27043  non_purchase             2                2
# 3338       36990  non_purchase             3                3
# 3339       36066  non_purchase             2                1
# 3340       33827  non_purchase             1                1
#
#       unique_categories  active_hours  view_count  cart_count  session_count  \
# 0                     1      0.063611           2           1              2
# ...

# %%
sns.scatterplot(data = df, x = "total_events", y = "active_hours")
# Out:
# <Axes: xlabel='total_events', ylabel='active_hours'>
